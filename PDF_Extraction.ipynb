# %% [markdown]
# <a href="https://colab.research.google.com/github/marshaniswah/Oleh-oleh/blob/main/PDF_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install pypdf
# Out:
# Collecting pypdf
#   Downloading pypdf-4.1.0-py3-none-any.whl (286 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.1/286.1 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: pypdf
# Successfully installed pypdf-4.1.0

# %%
from pypdf import PdfReader

reader = PdfReader("/content/sample_data/FTE-CD-123_edited-PBD(1).pdf")
text = ""
for page in reader.pages:
    text += page.extract_text() + "\n"
print(text)
# Out:
# DOKUMEN PROPOSAL CAPSTONE (CD 1 -3)
#
#
#
#
#
#
#
#
#
#
#
# Dashboard Management System  untuk Standarisasi Inkubator
# Bayi Berbasis Artificial Intelligence Decision Making
# Oleh :
#
# Sadam Al Rasyid/1101210112
# Marshaniswah Syamsul/1101210153
# Fakhriadi Rasyaad/1101210301
# Reynaldi  Tryana Graha /110121 3117
#
#
#
# PRODI S1 TEKNIK TELEKOMUNIKASI
# FAKULTAS TEKNIK ELEKTRO
# UNIVERSITAS TELKOM
# BANDUN G
# 2024
#
# i
#
#
# Lembar Pengesahan Dokumen
#
# Judul Capstone Design   :  Dashboard Management System  untuk Standarisasi
# Inkubator Bayi Berbasis Artificial Intelligence Decision
# Making
# Jenis Dokumen   :  Proposal capstone
# Nomor Dokumen   :  FTE CD 1 -3
# Nomor Revisi   :  …. (sesuaikan dengan jumlah revisi)
# Tanggal Pengesahan   :  dd/mm/yyyy
# Fakultas   :  Fakultas Teknik Elektro
# Program Studi   :  S1 Telekomunikasi
# Jumlah Halaman   :  ….
#
# Data Pemeriksaan dan Persetujuan
# Ditulis Oleh
#   Nama   : Sadam Al Rasyid   Jabatan   : Mahasiswa
# NIM
#
#   :  1101210112  Tanda Tangan
#
# Nama   : Marshaniswah Syamsul   Jabatan   : Mahasiswa
# NIM
#
#
#  : 1101210153  Tanda Tangan
#
# Nama    : Fakhriadi Rasyaad   Jabatan   : Mahasiswa
# NIM
#
#   : 1101210301  Tanda Tangan
#
# Nama    : Reynaldhi Tryana Graha  Jabatan   : Mahasiswa
# NIM
#
#
#
#
#
#
#
#  : 110121 3117
#  Tanda Tangan
#
#
# ii
#
#
#
#
# Disetujui Oleh   Nama   : Suryo Adhi Wibowo , S.T., M.T., Ph.D  Jabatan   : Pembimbing 1
# Tanggal
#
#
#   :  Tanda Tangan
# Nama   :  Jabatan   : Pembimbing 2
# Tanggal
#
#
#   :  Tanda Tangan
#
#
# iii
#
#
# Timeline Revisi Dokumen
#
# Versi,
# Tanggal  Revisi  Perbaikan yang dilakukan  Halaman
# Revisi
# 1, 22 Maret
# 2022  Latar belakang
# diperjelas akar
# masalahnya  Ditambahkan data -data yang
# mendukung masalah yang
# diangkat  3,4
# Spesifikasi model
# mohon dibuat lebih
# detail  Spesifikasi model sudah
# ditambahkan detail yang lebih
# lengkap antara lain :
# 1. Flowchart sistem
# 2. Fungsi setiap node
# pada sistem  13,14
#
#
#
#
#
# 1
#
#
# CD-1 GAGASAN
#
# 1.1 D eskripsi Umum Masalah dan Kebutuhan
# Angka kematian bayi neonatal  (usia 0 -28 hari) di Indonesia cukup tinggi . Di Asia
# Tenggara, Indonesia menempati peringkat 5 dengan angka 11,7 per 1000 bayi lahir  [1].
# Tingginya angka kematian ini  biasanya diakibatkan oleh kelahiran prematur  atau masalah
# kesehatan yang serius . Untuk bayi dengan kondisi tersebut , inkubator bayi menjadi alat medis
# yang penting untuk membantu mereka bertahan hidup . Inkubator bayi sangat penting untuk
# membantu bayi prematur atau bayi dengan masalah kesehatan untuk bertahan hidup di luar
# rahim. Tingginya angka kematian bayi neonatal di Indonesia  menjadikan penggunaan
# inkubator menjadi krusial dalam penanganan bayi -bayi dengan kondisi  tersebut .
# Di sisi lain, s tandarisasi alat-alat kesehatan merupakan hal yang penting untuk
# memastikan bahwa peralatan medis yang digunakan, termasuk inkubator bayi . Demi
# melindungi keselamatan, keamanan, kesehatan, dan lingkungan hidup, Kementerian/Lembaga
# Pemerintah Nonkementerian dapat mewajibkan SNI  (Standar Nasiona l Indonesia ) untuk
# produk -produk tertentu melalui peraturan menteri/kepala lembaga  [2]. Sehingga, standarisasi
# untuk alat kesehatan seperti inkubator bayi merupakan  hal yang wajib dilakukan untuk
# menjami n keamanan dan kualitas nya.
# Proses penilaian standarisasi inkubator bayi di Indonesia sendiri masih dilakukan secara
# manual . Petugas akan mengecek satu -satu kesesuain inkubator bayi dengan parameter yang
# telah ditetapkan oleh SNI. Karena dikerjakan secara manual, maka memungkinkan terjadi
# kesalahan dan ketidakakuratan saat menilai parameter dari inkubator bayi.  Selain itu,
# pengerjaan akan cenderung  lebih lama karena data yang didapat dari standarisasi dicatat secara
# manual.
# Kekurangan dari proses penilaian standarisasi yang ada sekarang tentu mempengaruhi
# kinerja penilaian serta hasilnya . Karena  prosesnya  dilakukan secara manual , penilaian akan
# rentan terhadap kesalahan . Hal tersebut akan berdampak pada  aspek teknologi dimana
# penilaian standarisasi inkubator bayi tidak dapat didokumentasikan dengan baik, pengerjaan
# lebih lama serta hasil yang tidak akurat . Ketidakakuratan berdampak pada aspek ekonomi yaitu
# dapat mengakibatkan  proses standarisasi  dilakukan berkali kali  sehingga  biaya standarisasi
# akan membengkak.  Kesalahan dari penilaian standarisasi juga dapat berdampak pada pembuat
# inkubator bayi serta petuga s yang melakukan penilaian . Akibatnya, hal ini dapat berdampak ke
# 2
#
#
# aspek hukum yaitu  pelaku yang terkait dapat dikenakan sanksi berupa denda maupun pidana
# penjar a.
# Solusi yang ada  saat ini  belum dapat menjawab permasalahan yang telah dipaparkan.
# Keterbatasan yang tidak dapat dihindari saat proses  penilaian standarisasi secara manual
# mengakibatkan perlunya  solusi yang baru . Solusi tersebut diharapkan dapat memberikan
# manfaat yang signifikan dalam meningkatkan kualitas perawatan bayi neonatal di Indonesia.
# 1.2 Analisa Masalah
# Proses  penilaian standardisasi yang masih manual menjadi masalah utama dari hadirnya
# Dashboard Management System ini. Masalah tersebut menimbulkan beberapa masalah di
# berbagai aspek seperti aspek teknologi , ekonomi , dan hukum . Berikut adalah rincian setiap
# aspek tersebut.
# 1.2.1 Aspek Teknologi
#  Pada aspek teknologi, prosedur pengujian manual memiliki beberapa permasalahan
# yang dapat mempengaruhi kinerja standarisasi secara signifikan. Permasalahan tersebut seperti
# prosesnya memakan waktu  lebih lama . Akibatknya, proses standarisasi lebih la mbat.  Selain
# itu, tidak  adanya  konsep dokumentasi yang jelas . Salah satu faktor penyebab kesalahan utama
# saat melakukan pekerjaan adalah kurangnya dokumentasi  [3]. Tanpa dokumentasi yang jelas,
# sulit bagi tenaga kerja standarisasi untuk mengikuti prosedur penguj ian. Akibatnya dapat
# menimbulkan ketidakpastian dan kesalahan dalam pelaksanaan standarisasi. Terakhir, rentan
# terhadap kesalahan manusia. Kesalahan manusia adalah faktor penyebab utama  antara 70 -80%
# dari sebagian besar kegagalan peralatan, insiden, dan kecelakaan  [4]. Dalam pengujian secara
# manual, risiko kesalahan manusia sangat  tinggi. Ini dapat mengakibatkan inkonsistensi dan
# hasil pengujian yang tidak akurat .
# 1.2.2 Aspek Ekonomi
# Dari risiko kesalahan manusia yang tinggi pada aspek teknologi, kesalahan pada
# standarisasi inkubator  bayi tidak dapat dihindari. Kesalahan tersebut mengakibatkan proses
# dari standarisasi dapat terjadi berulang kali . Proses tersebut tentunya memerlukan biaya yang
# tidak kecil.  Biaya pengurusan label SNI sebesar 10 -40 juta  [5]. Akibatnya terdapat
# pembengkakan biaya operasional secara keseluruhan  sehingga dapat membebani anggaran
# standarisasi.
# Selain itu, kesalahan saat proses pengecekan parameter standarisasi dapat berdampak
# pada perusahaan kedepannya.  Sebagai contoh p ada desember 2023, terdapat skandal
# pemalsuan uji keselamatan mobil daihatsu. Efek dari skandal tersebut membuat  Daihatsu
# 3
#
#
# menghentikan produksi  mobilnya di Jepang  yang  mengakibatkan hilangnya kepercayaan
# pelanggan dan terancam mengalami kerugian sebesar  US$ 700 atau setara dengan Rp 10,8
# triliun  [6].  Dari kejadian pada mobil Daihatsu tersebut , dampak dari kesalahan saat proses
# penilaian  adalah perusahaan terancam mengalami kerugian  baik di sisi ekonomi maupun secara
# manufaktur.
# 1.2.3 Aspek Hukum
# Prosedur pengujian manual yang tidak terdokumentasi dengan baik dapat berpotensi
# melanggar persyaratan khusus keselamatan dasar dan kinerja esensial inkubator  infant . Di
# Indonesia, pemberlakuan SNI  wajib  dilakukan melalui penerbitan regulasi teknis oleh Badan
# SNI. Produk yang tidak memenuhi standar SNI dapat dikenai sanksi berupa pembekuan
# sementara atau pencabutan izin edar [2]. Pelanggaran terhadap regulasi SNI  diatur dalam UU
# standardisasi dan  penilaian kesesuain dan bab X tentang ketentuan pidana pasal 62 hingga 73 .
# Jika terbukti terlanggar, maka pelaku pelanggaran akan dikenakan sanksi penjara atau pidana
# denda.
# 1.3 Analis is Solusi yang Ada
# Terkait permasalahan  yang telah dipaparkan , solusi yang masih ada saat ini adalah
# penilaian standarisasi inkubator bayi secara manual.   Prosesnya terdiri dari pengisian dokumen
# untuk  kelengkapan standarisasi , pengecekan kelengkapan inkubator bayi , dan pengambilan
# keputusan apakah inkubator bayi tersebut  memenuhi parameter -parameter standarisasi yang
# berlaku. Dari solusi yang ada saat ini, terdapat keunggulan, kekurangan dan keterbatasan di
# proses -proses penilaiannya. Berikut rincian dari aspek -aspek tersebu t.
# Tabel 1. 1 Perbandingan aspek  terhadap  Solusi yang Ada
# Solusi  Aspek
# Keunggulan  Kekurangan  Keterbatasan
# Solusi
# yang
# sudah ada  • Penilaian manual
# mengecek
# parameter secara
# langsung
# sehingga dapat
# mencatat lebih
# detail  • Hasil penilaian
# manual lebih
# sulit di
# dokumentasikan
# • Penilaian
# manual
# membutuhkan • Lebih rentan
# terhadap
# kesalahan  dan
# ketidakakuratan
# karena human
# error
# • Penilaian manual
# dapat dipengaruhi
# 4
#
#
# • Tidak
# memerlukan
# perangkat atau
# perangkat lunak
# khusus sehingga
# secara biaya lebih
# hemat.
#  waktu yang
# tidak singkat
# • Lebih sulit
# untuk dianalisis
# dikarenakan
# data diambil
# dari penilaian
# manual  oleh pendapat
# pribadi dari
# petugas.
# • Data dari
# penilaian manual
# lebih sulit untuk
# dianalisis secara
# efektif
#
#  Dari rincian diatas, solusi yang ada saat ini belum bisa menjadi jawaban atas
# permasalahan ya itu, kesalahan dan ketidakakuratan analisis terhadap penilaian standarisasi.
# Oleh karena itu, diperlukan solusi yang dapat meminimalkan kesalahan serta dapat melakukan
# analisis secara akurat agar penilaian standarisasi dapat diberikan  sebenar -benarnya. Untuk
# menjawab permasalahan tersebut, berikut perincian analisis komparasi terhadap solusi yang
# ada dan solusi yang akan dirancang.
#
#  Tabel 1.2 Analisis Komparatif  Solusi yang Ada dengan Solusi yang Dirancang
# Aspek  Solusi
# Solusi yang ada  Solusi yang akan dirancang
# Akurasi  Karena dipengaruh oleh faktor
# manusia maka cenderung lebih
# rendah . Karena dibuat oleh sistem yang
# mengikuti standarisasi yang telah
# maka cenderung lebih tinggi .
# Efisiensi  Membutuhkan waktu lebih lama
# karena dilakukan secara manual . Lebih hemat waktu  karena sistem
# otomatis melakukan penilaian dan
# mengambil keputusan.
# Konsistensi  Lebih rendah karena penilaian dapat
# dipengaruh oleh pendapat dari
# petugas yang bisa berbeda.  Lebih tinggi karena sistem lebih
# dapat menjaga konsistensi
# penilaian .
# Dokumentasi  Lebih sulit, karena hasil penilaian
# harus dicatat secara manual . Karena dibuat oleh sistem yang
# mengikuti standarisasi yang telah
# maka cenderung lebih tinggi .
# 5
#
#
# Biaya  Lebih hemat, karena tidak
# memerlukan peralatan dan
# perangkat lunak khusus.  Lebih mahal karena memerlukan
# peralatan dan perangkat lunak serta
# maintanance  sistem secara berkala .
# Keterampilan  Membutuhkan keterampilan dan
# pelatihan khusus untuk melakukan
# penilaian manual.  Tidak memerlukan keterampilan
# khusus untuk menggunakan sistem
# otomatis.
#
# Dari analisis komparatif diatas, dapat diambil kesimpulan bahwa solusi yang akan
# dirancang dapat menjadi jawaban dari permasalahan yang telah dipaparkan. Kekurangan dan
# keterbatasan dari solusi yang ada dapat teratasi dengan solusi yang akan dirancang. Walaupun
# terdapat kekurangan seperti di aspek biaya  akan lebih mahal tetapi keakuratan dan konsistensi
# solusi yang akan dirancang mampu menjadi investasi jangka panjang bagi petugas penilaian
# standarisasi inkubator bayi.
# 1.4 Kesimpulan
# Berdasarkan permasalahan yang ada  dapat disimpulkan  bahwa  standarisasi inkubator
# bayi belum efisien dalam pelaksanaannya  yang masih dilakukan secara manual. Oleh karena
# itu, diajukan  solusi yang dapat  meningkatkan efektivitas, efisiensi, dan akurasi dalam proses
# penilaian standarisasi . Selain itu, solusi ini dapat meminimalkan ketergantungan pada prosedur
# manual yang rentan terhadap kesalahan manusia. Solusi yang diusulkan lebih menitikberatkan
# pada pengembangan  sistem  yang dapat mempermudah pengisian informasi standarisasi secara
# digital. Selain itu, integrasi kecerdasan buatan (Artificial Intelligence ) diharapkan dapat
# mengoto matiskan proses penilaian  sehingga dapat menghasilkan penilaian standarisasi yang
# lebih akura t.
#
#
# 6
#
#
# CD-2 SPESIFIKASI
#
# 2.1 Dasar Penentuan Spesifikasi
# Secara umum, CD -2 berfokus pada batasan ( constraint ) dan spesifikasi solusi yang akan
# dikembangkan. Aspek batasan dan spesifikasi merupakan hal yang penting dalam proses
# engineering design . Dengan adanya batasan dan spesifikasi, solusi tidak hanya berorientasi
# pada penyelesaian masalah saja, tetapi juga untuk mempersempit pilihan solusi mengingat
# terdapat beraneka ragam solusi untuk menyelesaikan suatu masalah. Pada dasarnya, dokumen
# CD-2 dibagi menjadi tiga bagian atau sub bab, yaitu: (1) dasar penentuan s pesifikasi, (2) daftar
# batasan dan spesifikasi, dan (3) metode pengukuran spesifikasi.
# Bagian pertama dokumen CD -2 adalah dasar penentuan spesifikasi. Bagian ini menjadi
# penting agar mahasiswa mengumpulkan dasar yang kuat dalam menentukan batasan dan
# spesifikasi. Dengan kata lain, mahasiswa tidak boleh mengada -ada dalam menentukan batasan
# dan spesifikasi. Dasar penentuan batasan dan spesifikasi dapat diperoleh dari berbagai literatur,
# antara lain: (1) aturan pemerintah, (2) standar industri, (3) spesifikasi produk/ solusi yang sudah
# ada, (4) pustaka yang bersumber dari buku atau paper, dan lai n sebagainya. Selain itu, batasan
# dan spesifikasi dapat bersumber dari wawancara dengan pengguna, calon pengguna, atau pihak
# yang dianggap ahli. Dalam hal sumber spesifikasi berasal dari wawancara, hasil wawancara
# dilampirkan di dalam dokumen CD -2.
#
#
# Gambar 2.1 Support vector machine
#
# Aturan tata tulis dalam penulisan dokumen capstone  adalah sebagai berikut.
# • Batang tubuh dokumen ditulis menggunakan font Times New Roman  berukuran 12.
# • Ukuran spasi 1,5.
# • Judul sub -bab ditulis tebal.
# • Tata letak diatur justified , kecuali pada gambar dan tabel yang diletakkan di tengah.
# • Setiap tabel dan gambar harus memiliki judul.
#
# 7
#
#
# • Judul gambar ditulis di bawah gambar. Judul tabel ditulis di atas tabel.
# • Penulisan sitasi dan referensi menggunakan format IEEE.
#
# 2.2 Batasan dan Spesifikasi
# Pada bagian ini, mahasiswa menyajikan daftar batasan dan spesifikasi solusi. Batasan
# dan spesifikasi yang memiliki sifat: (1) memiliki dasar yang jelas, (2) tidak ambigu, (3) terukur,
# (4) realistis, dan (5) abstrak terhadap pilihan solusi atau merek terten tu. Setiap spesifikasi juga
# perlu dilengkapi dengan deskripsi yang jelas tetapi tidak berkepanjangan. Mahasiswa dapat
# membuat daftar batasan atau spesifikasi terlebih dahulu dan kemudian menjelaskan spesifikasi
# dengan lebih rinci di bagian berikutnya. Spes ifikasi tidak boleh hanya satu aspek saja, misalnya
# aspek teknis. Mahasiswa perlu juga mencantumkan aspek ekonomi dan lain -lain.
#
# 2.3 Pengukuran/verifikasi spesifikasi
# Pada bagian ini, mahasiswa memaparkan pengukuran atas setiap setiap spesifikasi yang
# ditentukan pada sub -bab sebelumnya. Setiap spesifikasi harus memiliki prosedur
# pengukuran/verifikasi yang benar. Terdapat dua bagian yang harus ada pada setiap pengukuran
# spesifikasi, yaitu: (1) alat ukur/verifikasi dan (2) mekanisme pengukuran. Mahasiswa juga
# dapat mencantumkan pustaka -pustaka yang terkait dengan pengukuran spesifikasi.
#
# 2.4 Kesimpulan
# Bagian ini merupakan rangkuman dokumen CD -2. Secara umum, bagian ini meringkas daftar
# spesifikasi atas solusi yang akan diusulkan. Bagian ini juga meringkas hubungan antara
# spesifikasi yang ditetapkan dengan masalah yang dipaparkan di dalam dokumen CD -1.
#
# 8
#
#
# CD-3 DESAIN
#
# 3.1 Alternatif Usulan Solusi
# Bagian ini berisi ringkasan alternatif -alternatif solusi terkait masalah yang akan
# diselesaikan. Mahasiswa diwajibkan mengusulkan sekurang -kurangnya tiga alternatif solusi.
# Setiap solusi harus relevan dengan masalah dan memenuhi seluruh kriteria, batasan, dan
# spesifikasi yang ditetapkan di CD -2.
# Beberapa metode dapat digunakan untuk Menyusun alternatif usulan solusi. Metode yang
# pertama adalah melalui studi literatur. Melalui studi literatur, metode -metode yang berpotensi
# menjadi solusi atau bagian dari solusi diinventarisasi dan selanjutnya dikaj i dengan lebih detil.
# Metode yang kedua adalah melalui pengembangan beberapa desain kasar atau awal yang
# dilakukan dengan cepat dan paralel.
# Secara umum, tiap -tiap alternatif solusi dijelaskan secara ringkas. Materi paparan untuk
# setiap solusi meliputi: dasar pemilihan alternatif, fitur utama, fitur tambahan (jika ada), data
# pengujian awal jika berupa desain kasar (jika ada), prosedur pengopera sian, dan lain
# sebagainya.
#
# 3.2 Analisis dan Pemilihan Solusi
# Sub bab analisis dan pemilihan solusi terdiri dari dua bagian, yaitu: (1) parameter -
# parameter yang digunakan untuk menetapkan solusi dan (2) mekanisme pemilihan solusi.
# Beberapa parameter yang lazim digunakan untuk menyeleksi solusi antara lain: tingkat
# kesesuaian, biaya, waktu, kehandalan, sumber daya (manusia, alat, dan bahan) yang
# dibutuhkan, dan lain sebagainya. Mekanisme pemilihan solusi dapat dilakukan dengan
# berbagai metode. Salah satu metode yang umum adalah design matrix scoring atau engineering
# design matrix. Solusi terpilih dapat diambil dari alternatif solusi yang terbaik maupun
# penggabungan beberapa alternatif solusi.
#
# 3.3 Desain Solusi Terpilih
# Bagian ini berisi desain detail atas solusi yang terpilih (detailed engineering design).
# Paparan desain dapat dibagi menjadi dua bagian, yaitu diskripsi umum desain dan penjelasan
# detail atas desain tersebut.
# Materi detail terkait desain solusi dapat disesuaikan dengan karakteristik solusi. Adapun
# materi berdasarkan jenis solusinya adalah sebagai berikut.
# 9
#
#
# • Solusi berupa sistem/arsitektur/framework  berisi: arsitektur sistem, blok diagram
# sistem, dan lain -lain.
# • Solusi yang berupa perangkat lunak  berisi: flowchart, UML, data flow diagram,
# pseudocode, desain antarmuka, entiry relationship diagram (jika melibatkan penggunaan
# database), desain antarmuka aplikasi (jika menghasilkan aplikasi), dan lain sebagainya.
# • Solusi yang berupa perangkat keras  berisi: gambar teknis lengkap, desain PCB, modul -
# modul sistem, dan lain sebagainya.
# • Solusi yang berupa proses  berisi: flowchart atau bagan proses, deskripsi detail pada setiap
# proses, dan lain sebagainya.
# • Solusi yang berupa  model atau algoritma berisi: desain entitas model, flowchart, dan
# representasi matematis.
# Bagian ini juga memaparkan alat dan bahan yang digunakan dalam proses desain dan
# pengembangan. Pada solusi yang menghasilkan perangkat keras, bagian ini juga memaparkan
# bahan yang digunakan untuk membuat perangkat tersebut sekaligus mekanisme pembuatan
# perangkat. Di sisi lain, bagian ini juga memaparkan seluruh software yang digunakan untuk
# merancang maupun membuat solusi tersebut.
#
# 3.4 Jadwal dan Anggaran
# Bagian ini berisikan jadwal pengerjaan solusi dan rancangan anggaran yang dibutuhkan.
# Jadwal pengerjaan merupakan jadwal implementasi rancangan, pembuatan prototype, sampai
# dengan pengujian. Jadwal dapat ditulis dalam bentuk tabel maupun gant chart. Tingka t
# kedetilan jadwal dapat dalam bulan maupun minggu. Proses pengerjaan sedapat mungkin tidak
# lebih dari 6 bulan. Dengan demikian, operasionalitas pengerjaan dalam satu semester dapat
# dijaga. Bagian ini sedapat mungkin menyajikan rencana anggaran dan biaya ( RAB), terutama
# jika solusi yang dikembangkan berupa hardware . RAB dapat disusun berdasarkan dua fase,
# yaitu fase pengembangan/implementasi dan fase pengujian.
#
#
# 10
#
#
# DAFTAR PUSTAKA
#
# [1] “Angka Kematian Bayi Neonatal ASEAN, Indonesia Urutan Berapa? | Databoks,”
# databoks.katadata.co.id. https://databoks.katadata.co.id/datapublish/2022/11/22/angka -
# kematian -bayi-neonatal -asean -indonesia -urutan -berapa (diakses  Mar. 17, 2024)
# [2] “Balai Besar Kerajinan dan Batik,” bbkb.kemenperin.go.id.
# https://bbkb.kemenperin.go.id/index.php/post/read/sanksi_tegas_atas_pelanggaran_regul
# asi_sni_secara_wajib_yang_tertuang_dalam_undang_undang_no_20_tahun_2014_0#:~:t
# ext=Pasal%2067%20%3A%20Setiap%20ora ng%20yang (accessed Mar. 14, 2024).
# [3] M. Nkosi, K. Gupta, and M. Mashinini, “Causes and Impact of Human Error in
# Maintenance of Mechanical Systems,” MATEC Web of Conferences, vol. 312, p. 05001,
# 2020,  doi: https://doi.org/10.1051/matecconf/202031205001 .
# [4] D. Pons and K. Dey, “Aviation Human Error Modelled as a Production Process,” The
# Ergonomics Open Journal, vol. 8, no. 1, pp. 1 –12, Jan. 2015, doi:
# https://doi.org/10.2174/1875934301508010001 .
# [5] “Langkah Mengurus Label SNI - BSN - Badan Standardisasi Nasional - National
# Standardization Agency of Indonesia - Setting the Standard in Indonesia ISO SNI WTO,”
# Bsn.go.id, 2024. https://bsn.go.id/main/berita/detail/12440/langkah -mengurus -label -sni
# (access ed Mar. 17, 2024).
# [6] D. Virovac, A. Domitrović, and E. Bazijanac, “The Influence of Human Factor in Aircraft
# Maintenance,” PROMET - Traffic&Transportation, vol. 29, no. 3, pp. 257 –266, Jun. 2017,
# doi: https://doi.org/10.7307 /ptt.v29i3.2068 .
